# %% [markdown]
# # Module 4 - Simple Logic

# %% [markdown]
# ## If statements
#
# <div>
# <img src="attachment:15f890ee-e059-48e6-a9be-5fd84773a525.png" width="300"/>
#
# https://www.geeksforgeeks.org/python3-if-if-else-nested-if-if-elif-statements/
# </div>
#
# <br />
#
# Python Format:
#
# ```
# if condition:
#     #code that runs if condition is 'True'
# ```

# %%
test_expression = True

if test_expression == True:
    print('Body of if')
    
print('Statement just below if')

# %%
test_expression = True

if test_expression:
    print('Body of if')
    
print('Statement just below if')

# %%
test_expression = False

if test_expression:
    print('Body of if')
    
print('Statement just below if')

# %%
test_expression = False

if test_expression:
    print('Body of if')
    
    print('Statement just below if')

# %% [markdown]
# ***Indentations matter!***

# %%
spo2 = 85
#spo2 = 96
#spo2 = 96.0
#spo2 = '96'

if spo2 > 95:
    print('Patient is good')
    
print('rest of code')

# %% [markdown]
# ## If - Else
#
# <div>
# <img src="attachment:75faaba9-c549-430e-a07f-7a2bbd006bec.png"/, width="200"/>
# </div>
# <br />
#
# Python Format:
#
# ```
# if condition:
#     #code that runs if condition is 'True'
# else:
#     #code that runs if condition is 'False'
# ```

# %%
test_expression = True

if test_expression:
    print('Body of if')
else:
    print('Failed expression....Body of else')
    
print('Statement just below if')

# %%
test_expression = False

if test_expression:
    print('Body of if')
else:
    print('Failed expression....Body of else')
    
print('Statement just below if')

# %%
spo2 = 85
#spo2 = 96

if spo2 > 95:
    print('Patient is good')
else:
    print('Patient is not good')

print('rest of code')

# %%
diagnoses = ['splenomagoly', 'enlarged lymph node', 'fatigue']
#diagnoses = ['splenomagoly', 'enlarged lymph node']

if 'splenomagoly' in diagnoses and 'fatigue' in diagnoses:
    print('patient may have lymphoma')
else:
    print('patient may be OK!')

# %% [markdown]
# # If - ElIf - Else
#
# <div>
# <img src="attachment:e5af1c5a-ddea-4232-b389-1cf637601591.png" width="400"/>
# </div>
#
# <br />
#
# Python Format:
#
# ```
# if condition1:
#     #code that runs if condition1 is 'True'
# elif condition2:
#     #code that runs if condition1 is 'False' AND condition 2 is 'True'
# .
# .
# .
# elif conditionN:
#     #code that runs if ALL previous conditions are 'False' AND conditionN is 'True'
# .
# .
# .
# else:
#     #code that runs if All previous condition are 'False'
# ```

# %%
condition1 = True
condition2 = True

#condition1 = False
#condition2 = False

#condition1 = True
#condition2 = False

#condition1 = False
#condition2 = True

if condition1:
    print('condition1 Met')
elif condition2:
    print('condition1 was NOT met, condition2 met')
else:
    print('neither condition1 nor condition2 were met')
    
print('after if statement')

# %% [markdown]
# # Nested Ifs

# %%
cond1 = False
cond2 = True

if cond1:
    print('if-beginning')
    if cond2:
        print('if-if')
        print('cond1 True AND cond2 True')
    else:
        print('if-else')
        print('cond1 True, but not cond2')
    print('if-end')
else:
    print('else')

print('after if')

# %%
#SIRS (systemic inflammatory response syndrome) criteria -> used to identify septic patients
hr = 92 #beats/min
temp = 39 #deg celsius

if hr > 90:
    if temp > 38 or temp < 36:
        print('Risk for SIRS')
    else:
        print('Minimal Risk for SIRS')
else:
    print('no risk for SIRS')

# %% [markdown]
# #### if-else vs. if-if
#
# Why not just use 2 if statements??

# %%
condition1 = True
condition2 = True

#condition1 = False
#condition2 = False

#condition1 = True
#condition2 = False

#condition1 = False
#condition2 = True

if condition1:
    print('condition1 Met')
if condition2:
    print('condition2 met')
else:
    print('condition2 NOT met')
    
print('after if statement')

# %% [markdown]
# ***This is where you have to think about your program and what real-world scenario you're trying to model***
#
# * In an if-if statement, both are independent from each other -> both can be run
# * In an if-else statement, they are dependent -> only one can be run

# %%
#SIRS (systemic inflammatory response syndrome) criteria -> used to identify septic patients
hr = 92 #beats/min
temp = 39 #deg celsius

if hr > 90:
    if temp > 38 or temp < 36:
        print('Risk for SIRS')
    else:
        print('Minimal Risk for SIRS')
else:
    print('no risk for SIRS')
